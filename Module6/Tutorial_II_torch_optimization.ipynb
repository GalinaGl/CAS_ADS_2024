# %% [markdown]
# ## Tutorial II: Optimization in **pytorch** and NN introduction
#
# <p>
# Bern Winter School on Machine Learning, 2024<br>
# Prepared by Mykhailo Vladymyrov and Matthew Vowels.
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %%
# time to teach without exercises 50mins

# %% [markdown]
# ## 1. Load necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ## 2. Linear fit
#
# Here we will solve optimization problem to perform linear regression. First we will generate training set of 80 data points and test set of 20, laying on a line with a random offset $$y = a_0 x + b_0 + \delta,$$ where $\delta$ is a random variable sampled from a uniform distribution with standard deviation equal to $s_0$.
# <!-- o.f.: 46, 48, 87, 99 | val better than train: 47, 56, 86. -->

# %%
a0 = 3  # 3
b0 = 5  # 5
s0 = 1  # 1

n_all = 100

np.random.seed(99)

# all samples
x_all = np.linspace(0, 10, n_all)  # 100 points
d_all = np.random.uniform(-s0, s0, size=n_all)
y_all = np.asarray([a0*x + b0 + d for x, d in zip(x_all, d_all)])

# randomize order and get 80% for training
idx = np.random.permutation(n_all)
n_train = n_all * 80 // 100

idx_train = idx[0:n_train]
idx_val = idx[n_train:]

x_train, y_train = x_all[idx_train], y_all[idx_train]

x_val, y_val = x_all[idx_val], y_all[idx_val]

plt.plot(x_train, y_train, "or", x_val, y_val, "b^")
plt.legend(('training points', 'validation points'),  loc='upper left');

# %% [markdown]
# We will then define loss function as the mean of squared residuals (distance from line along $y$) for the points.
#
# We will use [stochactic gradient descent](https://en.wikipedia.org/wiki/Stochastic_gradient_descent): on each iteration use only a fraction (`batch_size`) of all training set. In many cases training set is huge and cannot be fed on each iteration in principle. Also it can sometimes help the optimizer to properly explore the manifold.

# %%
class Linear(nn.Module):
    def __init__(self):
        super(Linear, self).__init__()
        self.a = nn.Parameter(torch.randn(1, requires_grad=True))
        self.b = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.a * x + self.b


def loss_f(true_y, y_predicted):
    return F.mse_loss(y_predicted, true_y)

# %%
len(x_train)
# Out:
# 80

# %%
# Define the model
model = Linear()

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.002)

# Define the number of epochs and batch size
epochs = 400
batch_size = 10


x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
y_train = torch.tensor(y_train)

x_val = torch.tensor(x_val)
y_val = torch.tensor(y_val)



# Training loop
train_loss_history = []
val_loss_history = []
for epoch in range(epochs):
    model.train()  # as opposed to model.eval()
    batch_losses = []
    permutation = torch.randperm(x_train.size()[0])


    for i in range(0, x_train.size()[0], batch_size):
        optimizer.zero_grad()

        indices = permutation[i:i+batch_size]
        batch_x, batch_y = x_train[indices], y_train[indices]

        # Forward pass
        outputs = model(batch_x)

        # Compute the loss
        loss = loss_f(batch_y, outputs)
        batch_losses.append(loss.item())
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    average_training_loss = np.mean(batch_losses)
    train_loss_history.append(average_training_loss)

    # Validation step (optional, for monitoring performance)
    model.eval()
    with torch.no_grad():
        val_outputs = model(x_val)
        val_loss = loss_f(y_val, val_outputs)
        val_loss_history.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss.item()}")
# Out:
# <ipython-input-7-e17f718b03fb>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
# <ipython-input-7-e17f718b03fb>:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train)
# <ipython-input-7-e17f718b03fb>:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_val = torch.tensor(x_val)
# <ipython-input-7-e17f718b03fb>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val)
# Epoch 1/400, Validation Loss: 47.169832362068775
# Epoch 2/400, Validation Loss: 8.073287292056083
# Epoch 3/400, Validation Loss: 4.762774072975505
# Epoch 4/400, Validation Loss: 4.477980199041925
# Epoch 5/400, Validation Loss: 4.390114710409653
# Epoch 6/400, Validation Loss: 4.320018408402117
# Epoch 7/400, Validation Loss: 4.257244328337927
# Epoch 8/400, Validation Loss: 4.192174030304207
# Epoch 9/400, Validation Loss: 4.124340884545766
# Epoch 10/400, Validation Loss: 4.055424444119291
# Epoch 11/400, Validation Loss: 3.9916417469706857
# Epoch 12/400, Validation Loss: 3.9391408734377578
# Epoch 13/400, Validation Loss: 3.873735862874215
# Epoch 14/400, Validation Loss: 3.821655924415296
# Epoch 15/400, Validation Loss: 3.749436233397727
# Epoch 16/400, Validation Loss: 3.684314868065826
# Epoch 17/400, Validation Loss: 3.6290010059632025
# Epoch 18/400, Validation Loss: 3.5741251441268007
# Epoch 19/400, Validation Loss: 3.5340126994163503
# Epoch 20/400, Validation Loss: 3.4641612634445975
# Epoch 21/400, Validation Loss: 3.4107675980282224
# Epoch 22/400, Validation Loss: 3.350324352273907
# Epoch 23/400, Validation Loss: 3.3047285539786118
# Epoch 24/400, Validation Loss: 3.2520721118075464
# Epoch 25/400, Validation Loss: 3.1960389931104976
# Epoch 26/400, Validation Loss: 3.1448370711096785
# Epoch 27/400, Validation Loss: 3.093101760504603
# Epoch 28/400, Validation Loss: 3.0467431633690785
# Epoch 29/400, Validation Loss: 3.003558291727845
# Epoch 30/400, Validation Loss: 2.95435488820022
# Epoch 31/400, Validation Loss: 2.909022427541975
# Epoch 32/400, Validation Loss: 2.8677342693531402
# Epoch 33/400, Validation Loss: 2.8203111277665958
# Epoch 34/400, Validation Loss: 2.7790796070816794
# Epoch 35/400, Validation Loss: 2.7526457113877534
# Epoch 36/400, Validation Loss: 2.7055438666948595
# Epoch 37/400, Validation Loss: 2.658350117100572
# Epoch 38/400, Validation Loss: 2.6204574917436387
# Epoch 39/400, Validation Loss: 2.5824322504725274
# Epoch 40/400, Validation Loss: 2.527811262824856
# Epoch 41/400, Validation Loss: 2.4953680401995513
# Epoch 42/400, Validation Loss: 2.459868384664857
# Epoch 43/400, Validation Loss: 2.4160480710252275
# Epoch 44/400, Validation Loss: 2.3797154100202618
# Epoch 45/400, Validation Loss: 2.339864484184981
# Epoch 46/400, Validation Loss: 2.3057609663568313
# Epoch 47/400, Validation Loss: 2.2727889862410633
# Epoch 48/400, Validation Loss: 2.237138306794883
# Epoch 49/400, Validation Loss: 2.21489185755902
# Epoch 50/400, Validation Loss: 2.1791662414693063
# Epoch 51/400, Validation Loss: 2.147195867353517
# Epoch 52/400, Validation Loss: 2.1197942121370765
# Epoch 53/400, Validation Loss: 2.083709346057817
# Epoch 54/400, Validation Loss: 2.055207542121738
# Epoch 55/400, Validation Loss: 2.0165028387589294
# Epoch 56/400, Validation Loss: 1.987662609078527
# Epoch 57/400, Validation Loss: 1.959911395368707
# Epoch 58/400, Validation Loss: 1.9396387462682434
# Epoch 59/400, Validation Loss: 1.9074135194380542
# Epoch 60/400, Validation Loss: 1.8853606343913056
# Epoch 61/400, Validation Loss: 1.8574587813479078
# Epoch 62/400, Validation Loss: 1.8309722973642095
# Epoch 63/400, Validation Loss: 1.8013702536137006
# Epoch 64/400, Validation Loss: 1.7741861574717888
# Epoch 65/400, Validation Loss: 1.748798020577727
# Epoch 66/400, Validation Loss: 1.7188859787629653
# Epoch 67/400, Validation Loss: 1.6988702048212025
# Epoch 68/400, Validation Loss: 1.6798594773863562
# Epoch 69/400, Validation Loss: 1.6575226605043505
# Epoch 70/400, Validation Loss: 1.6247569629073624
# Epoch 71/400, Validation Loss: 1.6043558738987822
# Epoch 72/400, Validation Loss: 1.581109950502066
# Epoch 73/400, Validation Loss: 1.5642281825396662
# Epoch 74/400, Validation Loss: 1.5433879112955444
# Epoch 75/400, Validation Loss: 1.5154935678670196
# Epoch 76/400, Validation Loss: 1.4953281985971636
# Epoch 77/400, Validation Loss: 1.4774850648275573
# Epoch 78/400, Validation Loss: 1.4609409116952627
# Epoch 79/400, Validation Loss: 1.439798597666115
# Epoch 80/400, Validation Loss: 1.4169446791220497
# Epoch 81/400, Validation Loss: 1.3927183453327678
# Epoch 82/400, Validation Loss: 1.3752948838851353
# Epoch 83/400, Validation Loss: 1.3594671500824091
# Epoch 84/400, Validation Loss: 1.3489883063784662
# Epoch 85/400, Validation Loss: 1.323030468613831
# Epoch 86/400, Validation Loss: 1.3113105657171844
# Epoch 87/400, Validation Loss: 1.2882259441784853
# Epoch 88/400, Validation Loss: 1.265998550013474
# Epoch 89/400, Validation Loss: 1.2514540457976335
# Epoch 90/400, Validation Loss: 1.2420307702974835
# Epoch 91/400, Validation Loss: 1.2180323332762637
# Epoch 92/400, Validation Loss: 1.2013707253964334
# Epoch 93/400, Validation Loss: 1.187164318779581
# Epoch 94/400, Validation Loss: 1.17473271203299
# Epoch 95/400, Validation Loss: 1.1687161938910493
# Epoch 96/400, Validation Loss: 1.1470224487898053
# Epoch 97/400, Validation Loss: 1.1305090856311524
# Epoch 98/400, Validation Loss: 1.1197938555424078
# Epoch 99/400, Validation Loss: 1.1032452291385941
# Epoch 100/400, Validation Loss: 1.090348384700703
# Epoch 101/400, Validation Loss: 1.0774972982830522
# Epoch 102/400, Validation Loss: 1.0631354009002376
# Epoch 103/400, Validation Loss: 1.0515522111550317
# Epoch 104/400, Validation Loss: 1.0380429451689563
# Epoch 105/400, Validation Loss: 1.0294157220383717
# Epoch 106/400, Validation Loss: 1.018180332011291
# Epoch 107/400, Validation Loss: 0.9967396308306581
# Epoch 108/400, Validation Loss: 0.9864634261287943
# Epoch 109/400, Validation Loss: 0.9754114618477976
# Epoch 110/400, Validation Loss: 0.962814338300352
# Epoch 111/400, Validation Loss: 0.9543678483743763
# Epoch 112/400, Validation Loss: 0.940982414628292
# Epoch 113/400, Validation Loss: 0.9438580102671512
# Epoch 114/400, Validation Loss: 0.9257684976990163
# Epoch 115/400, Validation Loss: 0.9154557387244733
# Epoch 116/400, Validation Loss: 0.8998836541825309
# Epoch 117/400, Validation Loss: 0.8923851577159088
# Epoch 118/400, Validation Loss: 0.8800655342510579
# Epoch 119/400, Validation Loss: 0.8730542946271049
# Epoch 120/400, Validation Loss: 0.8581435154146091
# Epoch 121/400, Validation Loss: 0.8542328897778851
# Epoch 122/400, Validation Loss: 0.8496472499832951
# Epoch 123/400, Validation Loss: 0.835740612018194
# Epoch 124/400, Validation Loss: 0.8297324212841385
# Epoch 125/400, Validation Loss: 0.8251304192596363
# Epoch 126/400, Validation Loss: 0.8162108765172926
# Epoch 127/400, Validation Loss: 0.8023933258309699
# Epoch 128/400, Validation Loss: 0.7960080305421944
# Epoch 129/400, Validation Loss: 0.7849896838044115
# Epoch 130/400, Validation Loss: 0.7745794753145259
# Epoch 131/400, Validation Loss: 0.767796718690348
# Epoch 132/400, Validation Loss: 0.760691387361204
# Epoch 133/400, Validation Loss: 0.7485878249401429
# Epoch 134/400, Validation Loss: 0.7463038105179028
# Epoch 135/400, Validation Loss: 0.7489798032197986
# Epoch 136/400, Validation Loss: 0.7312118229481119
# Epoch 137/400, Validation Loss: 0.7239902543670469
# Epoch 138/400, Validation Loss: 0.7116284146822712
# Epoch 139/400, Validation Loss: 0.7100568296362118
# Epoch 140/400, Validation Loss: 0.7022557116592987
# Epoch 141/400, Validation Loss: 0.7092766458874642
# Epoch 142/400, Validation Loss: 0.6972580915431896
# Epoch 143/400, Validation Loss: 0.6854917136118907
# Epoch 144/400, Validation Loss: 0.6824818364767016
# Epoch 145/400, Validation Loss: 0.6814160426585198
# Epoch 146/400, Validation Loss: 0.6669930636720948
# Epoch 147/400, Validation Loss: 0.662532773060234
# Epoch 148/400, Validation Loss: 0.6568081435158298
# Epoch 149/400, Validation Loss: 0.6640854485801958
# Epoch 150/400, Validation Loss: 0.6475212716489416
# Epoch 151/400, Validation Loss: 0.6469341312647743
# Epoch 152/400, Validation Loss: 0.6384453309232784
# Epoch 153/400, Validation Loss: 0.6279666119491297
# Epoch 154/400, Validation Loss: 0.6429287725315793
# Epoch 155/400, Validation Loss: 0.6241145197516339
# Epoch 156/400, Validation Loss: 0.6196328242577505
# Epoch 157/400, Validation Loss: 0.6153295862248469
# Epoch 158/400, Validation Loss: 0.6045523042575719
# Epoch 159/400, Validation Loss: 0.601432007574458
# Epoch 160/400, Validation Loss: 0.6013025160780612
# Epoch 161/400, Validation Loss: 0.6021952439106816
# Epoch 162/400, Validation Loss: 0.60936864026853
# Epoch 163/400, Validation Loss: 0.5839270538056007
# Epoch 164/400, Validation Loss: 0.5834786558935129
# Epoch 165/400, Validation Loss: 0.57697312709892
# Epoch 166/400, Validation Loss: 0.5750294855762532
# Epoch 167/400, Validation Loss: 0.5742015717470907
# Epoch 168/400, Validation Loss: 0.5696622431318787
# Epoch 169/400, Validation Loss: 0.5597054881286005
# Epoch 170/400, Validation Loss: 0.563617515909696
# Epoch 171/400, Validation Loss: 0.5567846209829297
# Epoch 172/400, Validation Loss: 0.5477487023904288
# Epoch 173/400, Validation Loss: 0.5484966531736656
# Epoch 174/400, Validation Loss: 0.5506236590866556
# Epoch 175/400, Validation Loss: 0.5516089884954632
# Epoch 176/400, Validation Loss: 0.538942560076163
# Epoch 177/400, Validation Loss: 0.5353783079642028
# Epoch 178/400, Validation Loss: 0.5294829714014413
# Epoch 179/400, Validation Loss: 0.5292948347265419
# Epoch 180/400, Validation Loss: 0.523689000240928
# Epoch 181/400, Validation Loss: 0.5220829625128168
# Epoch 182/400, Validation Loss: 0.5255501770658453
# Epoch 183/400, Validation Loss: 0.5265449676987235
# Epoch 184/400, Validation Loss: 0.5163939750583059
# Epoch 185/400, Validation Loss: 0.5185988032250333
# Epoch 186/400, Validation Loss: 0.5130953984750508
# Epoch 187/400, Validation Loss: 0.5091806879588214
# Epoch 188/400, Validation Loss: 0.5082763921995087
# Epoch 189/400, Validation Loss: 0.5042125371203068
# Epoch 190/400, Validation Loss: 0.5090031743371354
# Epoch 191/400, Validation Loss: 0.4943529381149313
# Epoch 192/400, Validation Loss: 0.49597593986388155
# Epoch 193/400, Validation Loss: 0.49529317143088714
# Epoch 194/400, Validation Loss: 0.4981393626264503
# Epoch 195/400, Validation Loss: 0.4920831048722767
# Epoch 196/400, Validation Loss: 0.49134802043490955
# Epoch 197/400, Validation Loss: 0.4859886755237146
# Epoch 198/400, Validation Loss: 0.48682062892935163
# Epoch 199/400, Validation Loss: 0.48554459259938587
# Epoch 200/400, Validation Loss: 0.4806389300274855
# Epoch 201/400, Validation Loss: 0.47706931814586007
# Epoch 202/400, Validation Loss: 0.4896915616348857
# Epoch 203/400, Validation Loss: 0.4762050324811521
# Epoch 204/400, Validation Loss: 0.47463504877209683
# Epoch 205/400, Validation Loss: 0.46918234325636626
# Epoch 206/400, Validation Loss: 0.4708259397076436
# Epoch 207/400, Validation Loss: 0.46331866281904566
# Epoch 208/400, Validation Loss: 0.46499386672234644
# Epoch 209/400, Validation Loss: 0.46268228584007953
# Epoch 210/400, Validation Loss: 0.4614365505404912
# Epoch 211/400, Validation Loss: 0.46081176214653946
# Epoch 212/400, Validation Loss: 0.4595282253454601
# Epoch 213/400, Validation Loss: 0.4584617481976335
# Epoch 214/400, Validation Loss: 0.4581824702006891
# Epoch 215/400, Validation Loss: 0.4546001626398943
# Epoch 216/400, Validation Loss: 0.4559438577311129
# Epoch 217/400, Validation Loss: 0.4488371104698764
# Epoch 218/400, Validation Loss: 0.4578642878420883
# Epoch 219/400, Validation Loss: 0.45234099524365756
# Epoch 220/400, Validation Loss: 0.4437852902503926
# Epoch 221/400, Validation Loss: 0.4498206427599524
# Epoch 222/400, Validation Loss: 0.44989600853613787
# Epoch 223/400, Validation Loss: 0.4427611859719892
# Epoch 224/400, Validation Loss: 0.442186716463007
# Epoch 225/400, Validation Loss: 0.44477294576915527
# Epoch 226/400, Validation Loss: 0.44204768034316383
# Epoch 227/400, Validation Loss: 0.4457847872677295
# Epoch 228/400, Validation Loss: 0.45072169427816516
# Epoch 229/400, Validation Loss: 0.43483882790656486
# Epoch 230/400, Validation Loss: 0.4443124314364505
# Epoch 231/400, Validation Loss: 0.4392390901671191
# Epoch 232/400, Validation Loss: 0.43511981949250755
# Epoch 233/400, Validation Loss: 0.43054406776152687
# Epoch 234/400, Validation Loss: 0.43581443780882373
# Epoch 235/400, Validation Loss: 0.43394906285363977
# Epoch 236/400, Validation Loss: 0.43075054285588515
# Epoch 237/400, Validation Loss: 0.4347291333679097
# Epoch 238/400, Validation Loss: 0.43707855154883657
# Epoch 239/400, Validation Loss: 0.43480385040322245
# Epoch 240/400, Validation Loss: 0.4419131023441607
# Epoch 241/400, Validation Loss: 0.43076488366969706
# Epoch 242/400, Validation Loss: 0.4342260342554184
# Epoch 243/400, Validation Loss: 0.4307765805525735
# Epoch 244/400, Validation Loss: 0.42976864779774876
# Epoch 245/400, Validation Loss: 0.4293548121795624
# Epoch 246/400, Validation Loss: 0.4259114949360896
# Epoch 247/400, Validation Loss: 0.4268185283752094
# Epoch 248/400, Validation Loss: 0.4286145963128762
# Epoch 249/400, Validation Loss: 0.4241817918602159
# Epoch 250/400, Validation Loss: 0.42888054295205047
# Epoch 251/400, Validation Loss: 0.42567439899424864
# Epoch 252/400, Validation Loss: 0.4273286455202415
# Epoch 253/400, Validation Loss: 0.4180608334923835
# Epoch 254/400, Validation Loss: 0.4226257745537185
# Epoch 255/400, Validation Loss: 0.41911035096173743
# Epoch 256/400, Validation Loss: 0.4180229286370006
# Epoch 257/400, Validation Loss: 0.4230573774268863
# Epoch 258/400, Validation Loss: 0.4267625728098269
# Epoch 259/400, Validation Loss: 0.4189913825536191
# Epoch 260/400, Validation Loss: 0.4244513300902567
# Epoch 261/400, Validation Loss: 0.42402236728580645
# Epoch 262/400, Validation Loss: 0.422186768463629
# Epoch 263/400, Validation Loss: 0.41847468619787015
# Epoch 264/400, Validation Loss: 0.4177921739341629
# Epoch 265/400, Validation Loss: 0.41477333956783297
# Epoch 266/400, Validation Loss: 0.4168855380991191
# Epoch 267/400, Validation Loss: 0.420747406032269
# Epoch 268/400, Validation Loss: 0.4167541664238333
# Epoch 269/400, Validation Loss: 0.4133685945026862
# Epoch 270/400, Validation Loss: 0.4132231217177257
# Epoch 271/400, Validation Loss: 0.4180190999565183
# Epoch 272/400, Validation Loss: 0.41838541766010345
# Epoch 273/400, Validation Loss: 0.41751415530298563
# Epoch 274/400, Validation Loss: 0.41363425432393097
# Epoch 275/400, Validation Loss: 0.42382967268043004
# Epoch 276/400, Validation Loss: 0.42343050429844925
# Epoch 277/400, Validation Loss: 0.41714732801137144
# Epoch 278/400, Validation Loss: 0.42449237235522297
# Epoch 279/400, Validation Loss: 0.42679278087524697
# Epoch 280/400, Validation Loss: 0.4112164905578627
# Epoch 281/400, Validation Loss: 0.41367205592693396
# Epoch 282/400, Validation Loss: 0.41354692612138455
# Epoch 283/400, Validation Loss: 0.4114672400355106
# Epoch 284/400, Validation Loss: 0.417958390169695
# Epoch 285/400, Validation Loss: 0.4118031407491108
# Epoch 286/400, Validation Loss: 0.41283573135952006
# Epoch 287/400, Validation Loss: 0.4122700874049451
# Epoch 288/400, Validation Loss: 0.41703458124830073
# Epoch 289/400, Validation Loss: 0.41692848410578287
# Epoch 290/400, Validation Loss: 0.41535603293216
# Epoch 291/400, Validation Loss: 0.4130549175380175
# Epoch 292/400, Validation Loss: 0.4182204555792339
# Epoch 293/400, Validation Loss: 0.4111095557955477
# Epoch 294/400, Validation Loss: 0.41013831640509213
# Epoch 295/400, Validation Loss: 0.40987646648034926
# Epoch 296/400, Validation Loss: 0.4118487619816548
# Epoch 297/400, Validation Loss: 0.41055455956553893
# Epoch 298/400, Validation Loss: 0.4130038585654268
# Epoch 299/400, Validation Loss: 0.4107627031801645
# Epoch 300/400, Validation Loss: 0.4111671150550714
# Epoch 301/400, Validation Loss: 0.4134697221696024
# Epoch 302/400, Validation Loss: 0.4141348057032709
# Epoch 303/400, Validation Loss: 0.4116903735464271
# Epoch 304/400, Validation Loss: 0.41332836145390417
# Epoch 305/400, Validation Loss: 0.41095413960636956
# Epoch 306/400, Validation Loss: 0.4185907333741069
# Epoch 307/400, Validation Loss: 0.41171682149483885
# Epoch 308/400, Validation Loss: 0.4168938281540095
# Epoch 309/400, Validation Loss: 0.4145096532065041
# Epoch 310/400, Validation Loss: 0.4148296707476652
# Epoch 311/400, Validation Loss: 0.41261144459741794
# Epoch 312/400, Validation Loss: 0.40859448909188234
# Epoch 313/400, Validation Loss: 0.41441537558757524
# Epoch 314/400, Validation Loss: 0.41186186598072155
# Epoch 315/400, Validation Loss: 0.4196106976868947
# Epoch 316/400, Validation Loss: 0.41242626546518474
# Epoch 317/400, Validation Loss: 0.4086765981447324
# Epoch 318/400, Validation Loss: 0.4110456124468098
# Epoch 319/400, Validation Loss: 0.4110271884429226
# Epoch 320/400, Validation Loss: 0.4054754619874593
# Epoch 321/400, Validation Loss: 0.41227432606358094
# Epoch 322/400, Validation Loss: 0.41647108674487754
# Epoch 323/400, Validation Loss: 0.42022074672020066
# Epoch 324/400, Validation Loss: 0.4186772260757231
# Epoch 325/400, Validation Loss: 0.41875998400899184
# Epoch 326/400, Validation Loss: 0.42338413859156426
# Epoch 327/400, Validation Loss: 0.42048123155900985
# Epoch 328/400, Validation Loss: 0.42033641416197687
# Epoch 329/400, Validation Loss: 0.4153145768261347
# Epoch 330/400, Validation Loss: 0.4124596317926268
# Epoch 331/400, Validation Loss: 0.4108279945103894
# Epoch 332/400, Validation Loss: 0.40726583769378466
# Epoch 333/400, Validation Loss: 0.4137479948730361
# Epoch 334/400, Validation Loss: 0.41294103741186544
# Epoch 335/400, Validation Loss: 0.41412944334101914
# Epoch 336/400, Validation Loss: 0.4110073907709831
# Epoch 337/400, Validation Loss: 0.41503468156662937
# Epoch 338/400, Validation Loss: 0.4187974721306701
# Epoch 339/400, Validation Loss: 0.41773504782326365
# Epoch 340/400, Validation Loss: 0.41038485622514276
# Epoch 341/400, Validation Loss: 0.4105414540370996
# Epoch 342/400, Validation Loss: 0.41415382675073176
# Epoch 343/400, Validation Loss: 0.4163643386110517
# Epoch 344/400, Validation Loss: 0.4178504836893591
# Epoch 345/400, Validation Loss: 0.41593952278404434
# Epoch 346/400, Validation Loss: 0.4137550802100806
# Epoch 347/400, Validation Loss: 0.412882402299765
# Epoch 348/400, Validation Loss: 0.418010508464368
# Epoch 349/400, Validation Loss: 0.4116303770934609
# Epoch 350/400, Validation Loss: 0.41651996316405987
# Epoch 351/400, Validation Loss: 0.41914250212429005
# Epoch 352/400, Validation Loss: 0.41432108314492877
# Epoch 353/400, Validation Loss: 0.41746161375559865
# Epoch 354/400, Validation Loss: 0.41165593237032905
# Epoch 355/400, Validation Loss: 0.4141408777302994
# Epoch 356/400, Validation Loss: 0.41315328102863036
# Epoch 357/400, Validation Loss: 0.4235786753354379
# Epoch 358/400, Validation Loss: 0.4286451039711193
# Epoch 359/400, Validation Loss: 0.426508270629214
# Epoch 360/400, Validation Loss: 0.42173444989037423
# Epoch 361/400, Validation Loss: 0.4219212181967807
# Epoch 362/400, Validation Loss: 0.41778612483246225
# Epoch 363/400, Validation Loss: 0.41842025287861506
# Epoch 364/400, Validation Loss: 0.41818921279885546
# Epoch 365/400, Validation Loss: 0.41576063047069456
# Epoch 366/400, Validation Loss: 0.4163184600629046
# Epoch 367/400, Validation Loss: 0.4140201124054116
# Epoch 368/400, Validation Loss: 0.42822074246296304
# Epoch 369/400, Validation Loss: 0.41797912463883835
# Epoch 370/400, Validation Loss: 0.41768910102243134
# Epoch 371/400, Validation Loss: 0.4227067187234178
# Epoch 372/400, Validation Loss: 0.4230160992803828
# Epoch 373/400, Validation Loss: 0.4185453016231799
# Epoch 374/400, Validation Loss: 0.4190417008295998
# Epoch 375/400, Validation Loss: 0.4184797859511595
# Epoch 376/400, Validation Loss: 0.42396986161852723
# Epoch 377/400, Validation Loss: 0.41813290432777706
# Epoch 378/400, Validation Loss: 0.41747455373103576
# Epoch 379/400, Validation Loss: 0.42229441750672636
# Epoch 380/400, Validation Loss: 0.4237427403880938
# Epoch 381/400, Validation Loss: 0.4272620444585266
# Epoch 382/400, Validation Loss: 0.42760922658599715
# Epoch 383/400, Validation Loss: 0.42268648015839183
# Epoch 384/400, Validation Loss: 0.4192057510455237
# Epoch 385/400, Validation Loss: 0.4191638821533469
# Epoch 386/400, Validation Loss: 0.42090406327858165
# Epoch 387/400, Validation Loss: 0.4242943312192324
# Epoch 388/400, Validation Loss: 0.42173277291770794
# Epoch 389/400, Validation Loss: 0.41838509996610507
# Epoch 390/400, Validation Loss: 0.41774353008113624
# Epoch 391/400, Validation Loss: 0.4215837825270075
# Epoch 392/400, Validation Loss: 0.42162592932318627
# Epoch 393/400, Validation Loss: 0.4245837392162811
# Epoch 394/400, Validation Loss: 0.42549253177186885
# Epoch 395/400, Validation Loss: 0.4290111722693125
# Epoch 396/400, Validation Loss: 0.42288821521652303
# Epoch 397/400, Validation Loss: 0.4238713378128282
# Epoch 398/400, Validation Loss: 0.42202496374378473
# Epoch 399/400, Validation Loss: 0.4180073217953807
# Epoch 400/400, Validation Loss: 0.42357818901999567

# %%
a_val, b_val = model.a.item(), model.b.item()

# Generate predictions for plotting
end_fit_x = [x_all[0], x_all[-1]]
end_fit_y = [a_val * x + b_val for x in end_fit_x]
true_fn_y = [a0 * x + b0 for x in end_fit_x]  # Assuming a0 and b0 are known true values

# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plotting data points and model predictions
axs[0].plot(x_train, y_train, 'ro', x_val, y_val, 'b^', end_fit_x, end_fit_y, 'g')
axs[0].legend(('training points', 'test points', 'final fit'), loc='upper left')

# Assuming training and validation loss history are stored in lists: train_loss_history and val_loss_history
epochs = range(1, len(train_loss_history) + 1)

# Plotting loss history
axs[1].semilogy(epochs, train_loss_history, 'r')
axs[1].semilogy(epochs, val_loss_history, 'b')
axs[1].legend(('training loss', 'validation loss'), loc='upper right')

plt.show()

# %%
a0 = 3  # 3
b0 = 5  # 5
s0 = 14  # 1

n_all = 100

np.random.seed(99)

# all samples
x_all = np.linspace(0, 10, n_all)  # 100 points
d_all = np.random.uniform(-s0, s0, size=n_all)
y_all = np.asarray([a0*x + b0 + d for x, d in zip(x_all, d_all)])

# randomize order and get 80% for training
idx = np.random.permutation(n_all)
n_train = n_all * 80 // 100

idx_train = idx[0:n_train]
idx_val = idx[n_train:]

x_train, y_train = x_all[idx_train], y_all[idx_train]

x_val, y_val = x_all[idx_val], y_all[idx_val]

plt.plot(x_train, y_train, "or", x_val, y_val, "b^")
plt.legend(('training points', 'validation points'),  loc='upper left');

# %%
class Linear(nn.Module):
    def __init__(self):
        super(Linear, self).__init__()
        self.a = nn.Parameter(torch.randn(1, requires_grad=True))
        self.b = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.a * x + self.b


def loss_f(true_y, y_predicted):
    return F.mse_loss(y_predicted, true_y)

# %%
# Define the model
model = Linear()

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.002)

# Define the number of epochs and batch size
epochs = 400
batch_size = 25


x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
y_train = torch.tensor(y_train)

x_val = torch.tensor(x_val)
y_val = torch.tensor(y_val)



# Training loop
train_loss_history = []
val_loss_history = []
for epoch in range(epochs):
    model.train()  # as opposed to model.eval()
    batch_losses = []
    permutation = torch.randperm(x_train.size()[0])


    for i in range(0, x_train.size()[0], batch_size):
        optimizer.zero_grad()

        indices = permutation[i:i+batch_size]
        batch_x, batch_y = x_train[indices], y_train[indices]

        # Forward pass
        outputs = model(batch_x)

        # Compute the loss
        loss = loss_f(batch_y, outputs)
        batch_losses.append(loss.item())
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    average_training_loss = np.mean(batch_losses)
    train_loss_history.append(average_training_loss)

    # Validation step (optional, for monitoring performance)
    model.eval()
    with torch.no_grad():
        val_outputs = model(x_val)
        val_loss = loss_f(y_val, val_outputs)
        val_loss_history.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss.item()}")
# Out:
# <ipython-input-24-ada96524cb7e>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
# <ipython-input-24-ada96524cb7e>:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train)
# <ipython-input-24-ada96524cb7e>:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_val = torch.tensor(x_val)
# <ipython-input-24-ada96524cb7e>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val)
# Epoch 1/400, Validation Loss: 232.02208291473022
# Epoch 2/400, Validation Loss: 121.50233454768095
# Epoch 3/400, Validation Loss: 84.45983188213617
# Epoch 4/400, Validation Loss: 80.29431491130997
# Epoch 5/400, Validation Loss: 79.04774480375315
# Epoch 6/400, Validation Loss: 80.16342349890724
# Epoch 7/400, Validation Loss: 81.49306305236139
# Epoch 8/400, Validation Loss: 81.94636294370828
# Epoch 9/400, Validation Loss: 81.79518440211086
# Epoch 10/400, Validation Loss: 81.38719605667612
# Epoch 11/400, Validation Loss: 86.56521527560551
# Epoch 12/400, Validation Loss: 86.34843656021721
# Epoch 13/400, Validation Loss: 84.15851904668091
# Epoch 14/400, Validation Loss: 83.0217566779665
# Epoch 15/400, Validation Loss: 82.27157923009733
# Epoch 16/400, Validation Loss: 81.50978725863904
# Epoch 17/400, Validation Loss: 81.20941763193204
# Epoch 18/400, Validation Loss: 80.09564192871844
# Epoch 19/400, Validation Loss: 80.46597324764593
# Epoch 20/400, Validation Loss: 80.25674707679168
# Epoch 21/400, Validation Loss: 81.47976805827932
# Epoch 22/400, Validation Loss: 81.82087921976165
# Epoch 23/400, Validation Loss: 80.41240898282278
# Epoch 24/400, Validation Loss: 80.57354122083566
# Epoch 25/400, Validation Loss: 81.37713291285333
# Epoch 26/400, Validation Loss: 82.36792396654911
# Epoch 27/400, Validation Loss: 81.62254876142488
# Epoch 28/400, Validation Loss: 81.1947688933382
# Epoch 29/400, Validation Loss: 80.94138318782908
# Epoch 30/400, Validation Loss: 80.91688864907425
# Epoch 31/400, Validation Loss: 80.72826961620729
# Epoch 32/400, Validation Loss: 82.04572498513706
# Epoch 33/400, Validation Loss: 81.56030996513125
# Epoch 34/400, Validation Loss: 81.97422164016004
# Epoch 35/400, Validation Loss: 84.17041301510335
# Epoch 36/400, Validation Loss: 81.49600577848226
# Epoch 37/400, Validation Loss: 80.4359755436789
# Epoch 38/400, Validation Loss: 81.39267171427966
# Epoch 39/400, Validation Loss: 80.51070824884707
# Epoch 40/400, Validation Loss: 80.55558412944613
# Epoch 41/400, Validation Loss: 81.44230164558681
# Epoch 42/400, Validation Loss: 80.21056646039703
# Epoch 43/400, Validation Loss: 80.81673877241981
# Epoch 44/400, Validation Loss: 80.93761676964641
# Epoch 45/400, Validation Loss: 80.21170849375922
# Epoch 46/400, Validation Loss: 80.1427687730542
# Epoch 47/400, Validation Loss: 81.03088003037365
# Epoch 48/400, Validation Loss: 81.42181350778046
# Epoch 49/400, Validation Loss: 83.34615771563891
# Epoch 50/400, Validation Loss: 82.25177760332143
# Epoch 51/400, Validation Loss: 83.60912941880342
# Epoch 52/400, Validation Loss: 83.15289429479523
# Epoch 53/400, Validation Loss: 80.9680276708099
# Epoch 54/400, Validation Loss: 80.86774531953702
# Epoch 55/400, Validation Loss: 84.11838935007435
# Epoch 56/400, Validation Loss: 82.74443251499731
# Epoch 57/400, Validation Loss: 81.98067496371927
# Epoch 58/400, Validation Loss: 82.37435406889372
# Epoch 59/400, Validation Loss: 82.16160954942356
# Epoch 60/400, Validation Loss: 82.20677661046125
# Epoch 61/400, Validation Loss: 82.82019018152684
# Epoch 62/400, Validation Loss: 84.92898701338922
# Epoch 63/400, Validation Loss: 84.51948728126945
# Epoch 64/400, Validation Loss: 83.5205013481316
# Epoch 65/400, Validation Loss: 82.31162363878597
# Epoch 66/400, Validation Loss: 80.50975488512222
# Epoch 67/400, Validation Loss: 82.7751815558042
# Epoch 68/400, Validation Loss: 80.57212145509247
# Epoch 69/400, Validation Loss: 82.58384085336634
# Epoch 70/400, Validation Loss: 82.77554217596109
# Epoch 71/400, Validation Loss: 83.5673905221362
# Epoch 72/400, Validation Loss: 82.18180799641404
# Epoch 73/400, Validation Loss: 79.8013742049779
# Epoch 74/400, Validation Loss: 80.36825891237191
# Epoch 75/400, Validation Loss: 81.30965324603012
# Epoch 76/400, Validation Loss: 83.01302798602862
# Epoch 77/400, Validation Loss: 83.48401807496543
# Epoch 78/400, Validation Loss: 82.84915265796526
# Epoch 79/400, Validation Loss: 82.13023386956652
# Epoch 80/400, Validation Loss: 83.44760980209297
# Epoch 81/400, Validation Loss: 81.64775703424066
# Epoch 82/400, Validation Loss: 80.33337008984363
# Epoch 83/400, Validation Loss: 84.33356056254448
# Epoch 84/400, Validation Loss: 82.43736285098711
# Epoch 85/400, Validation Loss: 82.87497151124487
# Epoch 86/400, Validation Loss: 85.0396488831725
# Epoch 87/400, Validation Loss: 86.21904574769113
# Epoch 88/400, Validation Loss: 84.87559206307574
# Epoch 89/400, Validation Loss: 84.33951577120392
# Epoch 90/400, Validation Loss: 81.48099374674158
# Epoch 91/400, Validation Loss: 82.97421382833087
# Epoch 92/400, Validation Loss: 81.24929428878605
# Epoch 93/400, Validation Loss: 81.77979811509445
# Epoch 94/400, Validation Loss: 81.7529648659691
# Epoch 95/400, Validation Loss: 85.58664984340199
# Epoch 96/400, Validation Loss: 84.15297747802808
# Epoch 97/400, Validation Loss: 81.84875187706619
# Epoch 98/400, Validation Loss: 80.57113562343424
# Epoch 99/400, Validation Loss: 79.97357818725577
# Epoch 100/400, Validation Loss: 80.5580737457959
# Epoch 101/400, Validation Loss: 80.87516728349127
# Epoch 102/400, Validation Loss: 82.87548570110974
# Epoch 103/400, Validation Loss: 83.8429861131089
# Epoch 104/400, Validation Loss: 83.65022943845955
# Epoch 105/400, Validation Loss: 86.49370017312728
# Epoch 106/400, Validation Loss: 88.65624319181794
# Epoch 107/400, Validation Loss: 87.48491382716176
# Epoch 108/400, Validation Loss: 85.95865339746639
# Epoch 109/400, Validation Loss: 85.44816021290504
# Epoch 110/400, Validation Loss: 84.89740245019685
# Epoch 111/400, Validation Loss: 83.03694623940157
# Epoch 112/400, Validation Loss: 80.92734968257764
# Epoch 113/400, Validation Loss: 82.29048840252315
# Epoch 114/400, Validation Loss: 84.34753882372198
# Epoch 115/400, Validation Loss: 83.02243740657738
# Epoch 116/400, Validation Loss: 85.17941374516211
# Epoch 117/400, Validation Loss: 81.43159676446164
# Epoch 118/400, Validation Loss: 80.75039751335737
# Epoch 119/400, Validation Loss: 80.83953620257078
# Epoch 120/400, Validation Loss: 81.63632276746668
# Epoch 121/400, Validation Loss: 82.96796295043944
# Epoch 122/400, Validation Loss: 82.71554007444078
# Epoch 123/400, Validation Loss: 82.511405983945
# Epoch 124/400, Validation Loss: 82.22775757810439
# Epoch 125/400, Validation Loss: 81.28252854714103
# Epoch 126/400, Validation Loss: 81.24638540851933
# Epoch 127/400, Validation Loss: 82.44602412820447
# Epoch 128/400, Validation Loss: 82.51691246560372
# Epoch 129/400, Validation Loss: 85.66533953122573
# Epoch 130/400, Validation Loss: 84.22099923036144
# Epoch 131/400, Validation Loss: 81.71681260510417
# Epoch 132/400, Validation Loss: 82.08780111225656
# Epoch 133/400, Validation Loss: 82.26225287237044
# Epoch 134/400, Validation Loss: 81.82253571123047
# Epoch 135/400, Validation Loss: 81.98708509555391
# Epoch 136/400, Validation Loss: 82.22456915511938
# Epoch 137/400, Validation Loss: 81.5249636968388
# Epoch 138/400, Validation Loss: 83.87039020992992
# Epoch 139/400, Validation Loss: 85.08044593635955
# Epoch 140/400, Validation Loss: 84.67917116746901
# Epoch 141/400, Validation Loss: 84.02301204518479
# Epoch 142/400, Validation Loss: 86.27896102095579
# Epoch 143/400, Validation Loss: 84.21351288362567
# Epoch 144/400, Validation Loss: 83.28955912945686
# Epoch 145/400, Validation Loss: 85.98144544504153
# Epoch 146/400, Validation Loss: 86.33325002484048
# Epoch 147/400, Validation Loss: 85.3887535242011
# Epoch 148/400, Validation Loss: 85.18508715591521
# Epoch 149/400, Validation Loss: 82.52183623391151
# Epoch 150/400, Validation Loss: 84.27558379733998
# Epoch 151/400, Validation Loss: 86.66154415109465
# Epoch 152/400, Validation Loss: 87.4033878435931
# Epoch 153/400, Validation Loss: 85.9595831195468
# Epoch 154/400, Validation Loss: 83.60862013706539
# Epoch 155/400, Validation Loss: 83.01706878125447
# Epoch 156/400, Validation Loss: 83.032727954804
# Epoch 157/400, Validation Loss: 84.33313642260529
# Epoch 158/400, Validation Loss: 83.76155841227352
# Epoch 159/400, Validation Loss: 84.39623421779234
# Epoch 160/400, Validation Loss: 82.63315118463736
# Epoch 161/400, Validation Loss: 82.92690957808318
# Epoch 162/400, Validation Loss: 82.40555785568361
# Epoch 163/400, Validation Loss: 81.87978611097236
# Epoch 164/400, Validation Loss: 81.52498159717811
# Epoch 165/400, Validation Loss: 82.56325676904676
# Epoch 166/400, Validation Loss: 82.49046796197224
# Epoch 167/400, Validation Loss: 82.90652428767666
# Epoch 168/400, Validation Loss: 82.09984339342483
# Epoch 169/400, Validation Loss: 83.33392229936373
# Epoch 170/400, Validation Loss: 84.10588976969588
# Epoch 171/400, Validation Loss: 84.2793762368042
# Epoch 172/400, Validation Loss: 86.43640457575553
# Epoch 173/400, Validation Loss: 87.94807681300065
# Epoch 174/400, Validation Loss: 86.02473468975757
# Epoch 175/400, Validation Loss: 83.51360384683485
# Epoch 176/400, Validation Loss: 82.124764816784
# Epoch 177/400, Validation Loss: 82.08431829554873
# Epoch 178/400, Validation Loss: 83.37948911438546
# Epoch 179/400, Validation Loss: 84.31966496411886
# Epoch 180/400, Validation Loss: 85.88896128193736
# Epoch 181/400, Validation Loss: 83.24158399668968
# Epoch 182/400, Validation Loss: 82.98407649276336
# Epoch 183/400, Validation Loss: 84.91389940512056
# Epoch 184/400, Validation Loss: 84.13591697779528
# Epoch 185/400, Validation Loss: 84.69863008344723
# Epoch 186/400, Validation Loss: 87.33286442610952
# Epoch 187/400, Validation Loss: 88.44215733016001
# Epoch 188/400, Validation Loss: 89.80284102673444
# Epoch 189/400, Validation Loss: 86.16648989095134
# Epoch 190/400, Validation Loss: 86.47874789725907
# Epoch 191/400, Validation Loss: 85.32779330811562
# Epoch 192/400, Validation Loss: 85.18032113968427
# Epoch 193/400, Validation Loss: 86.39980580535894
# Epoch 194/400, Validation Loss: 88.08761563766883
# Epoch 195/400, Validation Loss: 90.30808673307615
# Epoch 196/400, Validation Loss: 85.4180144919469
# Epoch 197/400, Validation Loss: 88.96623355173509
# Epoch 198/400, Validation Loss: 84.5945725111109
# Epoch 199/400, Validation Loss: 86.83666867399765
# Epoch 200/400, Validation Loss: 86.95825003387917
# Epoch 201/400, Validation Loss: 83.3831601660606
# Epoch 202/400, Validation Loss: 88.09512648201458
# Epoch 203/400, Validation Loss: 87.62839941652578
# Epoch 204/400, Validation Loss: 84.76521744610515
# Epoch 205/400, Validation Loss: 85.75670108173941
# Epoch 206/400, Validation Loss: 85.12950189330559
# Epoch 207/400, Validation Loss: 85.12466280701393
# Epoch 208/400, Validation Loss: 83.29234318527186
# Epoch 209/400, Validation Loss: 82.54667028709704
# Epoch 210/400, Validation Loss: 83.94982213772877
# Epoch 211/400, Validation Loss: 86.23391166010013
# Epoch 212/400, Validation Loss: 85.24409914069199
# Epoch 213/400, Validation Loss: 84.8146010696394
# Epoch 214/400, Validation Loss: 84.7719252474549
# Epoch 215/400, Validation Loss: 84.50079760103195
# Epoch 216/400, Validation Loss: 83.21816851402673
# Epoch 217/400, Validation Loss: 83.58399645843957
# Epoch 218/400, Validation Loss: 85.09524636357216
# Epoch 219/400, Validation Loss: 84.97692684529872
# Epoch 220/400, Validation Loss: 82.76096611044781
# Epoch 221/400, Validation Loss: 82.84370620805362
# Epoch 222/400, Validation Loss: 82.69629414925404
# Epoch 223/400, Validation Loss: 83.01948234822922
# Epoch 224/400, Validation Loss: 84.58277414254552
# Epoch 225/400, Validation Loss: 84.08557226995015
# Epoch 226/400, Validation Loss: 83.22672122306442
# Epoch 227/400, Validation Loss: 82.66592578324968
# Epoch 228/400, Validation Loss: 84.22080228846285
# Epoch 229/400, Validation Loss: 84.46922815062348
# Epoch 230/400, Validation Loss: 84.86679849424075
# Epoch 231/400, Validation Loss: 84.06511339046679
# Epoch 232/400, Validation Loss: 84.61435683524773
# Epoch 233/400, Validation Loss: 86.58436782779867
# Epoch 234/400, Validation Loss: 88.20115948931245
# Epoch 235/400, Validation Loss: 86.6661057347186
# Epoch 236/400, Validation Loss: 86.27139735027795
# Epoch 237/400, Validation Loss: 86.98198686627447
# Epoch 238/400, Validation Loss: 85.94634935187257
# Epoch 239/400, Validation Loss: 84.33707941543098
# Epoch 240/400, Validation Loss: 85.01680781887198
# Epoch 241/400, Validation Loss: 86.88596753537607
# Epoch 242/400, Validation Loss: 86.94481811923939
# Epoch 243/400, Validation Loss: 86.9458304562214
# Epoch 244/400, Validation Loss: 84.07904475845712
# Epoch 245/400, Validation Loss: 84.58872248073116
# Epoch 246/400, Validation Loss: 84.58789438745424
# Epoch 247/400, Validation Loss: 85.55969386877979
# Epoch 248/400, Validation Loss: 84.30348298666253
# Epoch 249/400, Validation Loss: 84.49370453314486
# Epoch 250/400, Validation Loss: 85.6288436134508
# Epoch 251/400, Validation Loss: 86.7410132943651
# Epoch 252/400, Validation Loss: 88.19599215738388
# Epoch 253/400, Validation Loss: 85.43297305968844
# Epoch 254/400, Validation Loss: 85.54376572710251
# Epoch 255/400, Validation Loss: 86.00124328932594
# Epoch 256/400, Validation Loss: 85.21815454692822
# Epoch 257/400, Validation Loss: 84.9095491593027
# Epoch 258/400, Validation Loss: 85.99884512297783
# Epoch 259/400, Validation Loss: 85.58443626197167
# Epoch 260/400, Validation Loss: 84.04051708103275
# Epoch 261/400, Validation Loss: 84.6963695353476
# Epoch 262/400, Validation Loss: 87.53980828857371
# Epoch 263/400, Validation Loss: 83.96515067825332
# Epoch 264/400, Validation Loss: 84.64425992318382
# Epoch 265/400, Validation Loss: 84.37973428532196
# Epoch 266/400, Validation Loss: 84.53517466723055
# Epoch 267/400, Validation Loss: 86.13392908834321
# Epoch 268/400, Validation Loss: 86.97358132952895
# Epoch 269/400, Validation Loss: 87.91302555162302
# Epoch 270/400, Validation Loss: 85.71813925613108
# Epoch 271/400, Validation Loss: 83.97936189650554
# Epoch 272/400, Validation Loss: 85.78097520329193
# Epoch 273/400, Validation Loss: 85.51876178347732
# Epoch 274/400, Validation Loss: 89.29805553739821
# Epoch 275/400, Validation Loss: 86.7976969872897
# Epoch 276/400, Validation Loss: 85.30798940892994
# Epoch 277/400, Validation Loss: 85.00525475953366
# Epoch 278/400, Validation Loss: 83.29199478735389
# Epoch 279/400, Validation Loss: 83.34927243065482
# Epoch 280/400, Validation Loss: 82.79877135685506
# Epoch 281/400, Validation Loss: 84.7143993905838
# Epoch 282/400, Validation Loss: 85.9919843504496
# Epoch 283/400, Validation Loss: 88.20166234274492
# Epoch 284/400, Validation Loss: 85.15973900477084
# Epoch 285/400, Validation Loss: 84.37299703150202
# Epoch 286/400, Validation Loss: 84.34488085376519
# Epoch 287/400, Validation Loss: 83.63825552378857
# Epoch 288/400, Validation Loss: 83.335157004928
# Epoch 289/400, Validation Loss: 84.37793559702996
# Epoch 290/400, Validation Loss: 85.43615376665889
# Epoch 291/400, Validation Loss: 85.39516908089944
# Epoch 292/400, Validation Loss: 85.59991456574414
# Epoch 293/400, Validation Loss: 83.48063712976428
# Epoch 294/400, Validation Loss: 83.88460436218593
# Epoch 295/400, Validation Loss: 85.25955596775388
# Epoch 296/400, Validation Loss: 84.61157146359756
# Epoch 297/400, Validation Loss: 88.97636153489748
# Epoch 298/400, Validation Loss: 86.73972330739024
# Epoch 299/400, Validation Loss: 86.92864120237603
# Epoch 300/400, Validation Loss: 86.71655964058469
# Epoch 301/400, Validation Loss: 85.23803541959951
# Epoch 302/400, Validation Loss: 84.32848684038173
# Epoch 303/400, Validation Loss: 83.62667162828595
# Epoch 304/400, Validation Loss: 86.62411232045739
# Epoch 305/400, Validation Loss: 88.4218892044707
# Epoch 306/400, Validation Loss: 85.96316745995121
# Epoch 307/400, Validation Loss: 86.2355856930416
# Epoch 308/400, Validation Loss: 86.63291314912742
# Epoch 309/400, Validation Loss: 85.69841666864889
# Epoch 310/400, Validation Loss: 85.50259984132965
# Epoch 311/400, Validation Loss: 87.88996839974412
# Epoch 312/400, Validation Loss: 88.67680793388719
# Epoch 313/400, Validation Loss: 88.16472912565659
# Epoch 314/400, Validation Loss: 86.69821829807395
# Epoch 315/400, Validation Loss: 84.91552691774103
# Epoch 316/400, Validation Loss: 84.84511727504909
# Epoch 317/400, Validation Loss: 85.45052416037007
# Epoch 318/400, Validation Loss: 86.439086622129
# Epoch 319/400, Validation Loss: 84.40904387117446
# Epoch 320/400, Validation Loss: 86.70696246965784
# Epoch 321/400, Validation Loss: 86.65866859283042
# Epoch 322/400, Validation Loss: 87.11414336402608
# Epoch 323/400, Validation Loss: 87.16102526717108
# Epoch 324/400, Validation Loss: 86.83729891523132
# Epoch 325/400, Validation Loss: 87.55111373047036
# Epoch 326/400, Validation Loss: 88.59648806108382
# Epoch 327/400, Validation Loss: 87.35053357602074
# Epoch 328/400, Validation Loss: 88.09520127284839
# Epoch 329/400, Validation Loss: 87.78676430843191
# Epoch 330/400, Validation Loss: 88.84064787475407
# Epoch 331/400, Validation Loss: 87.9087273116833
# Epoch 332/400, Validation Loss: 85.92154347688219
# Epoch 333/400, Validation Loss: 87.89941623939019
# Epoch 334/400, Validation Loss: 89.71549770237853
# Epoch 335/400, Validation Loss: 87.96845596850396
# Epoch 336/400, Validation Loss: 85.83079939754053
# Epoch 337/400, Validation Loss: 87.38965461947855
# Epoch 338/400, Validation Loss: 87.11353333803063
# Epoch 339/400, Validation Loss: 88.38824419040347
# Epoch 340/400, Validation Loss: 87.37565212240779
# Epoch 341/400, Validation Loss: 87.8228554084008
# Epoch 342/400, Validation Loss: 85.07074551758198
# Epoch 343/400, Validation Loss: 84.86756035351286
# Epoch 344/400, Validation Loss: 87.33540173274284
# Epoch 345/400, Validation Loss: 87.33786727605917
# Epoch 346/400, Validation Loss: 85.9441432894487
# Epoch 347/400, Validation Loss: 85.46679414423599
# Epoch 348/400, Validation Loss: 85.55978100029537
# Epoch 349/400, Validation Loss: 83.96979891200515
# Epoch 350/400, Validation Loss: 83.6361901473362
# Epoch 351/400, Validation Loss: 83.43394349778859
# Epoch 352/400, Validation Loss: 83.62734381922505
# Epoch 353/400, Validation Loss: 84.2441951249839
# Epoch 354/400, Validation Loss: 85.50679523027728
# Epoch 355/400, Validation Loss: 83.61562835860677
# Epoch 356/400, Validation Loss: 85.37064017132924
# Epoch 357/400, Validation Loss: 87.1300730499725
# Epoch 358/400, Validation Loss: 84.69720976216257
# Epoch 359/400, Validation Loss: 84.64992565579728
# Epoch 360/400, Validation Loss: 85.34264340107411
# Epoch 361/400, Validation Loss: 86.42383129466698
# Epoch 362/400, Validation Loss: 84.41020950107932
# Epoch 363/400, Validation Loss: 86.16193548918072
# Epoch 364/400, Validation Loss: 86.23699417835346
# Epoch 365/400, Validation Loss: 87.16839682492369
# Epoch 366/400, Validation Loss: 89.19062994461484
# Epoch 367/400, Validation Loss: 87.41191412635581
# Epoch 368/400, Validation Loss: 88.57665958730561
# Epoch 369/400, Validation Loss: 88.45212839413723
# Epoch 370/400, Validation Loss: 85.70128782871458
# Epoch 371/400, Validation Loss: 88.14873057688399
# Epoch 372/400, Validation Loss: 86.11563144021868
# Epoch 373/400, Validation Loss: 90.21555971362082
# Epoch 374/400, Validation Loss: 89.49323115854776
# Epoch 375/400, Validation Loss: 90.64548288671807
# Epoch 376/400, Validation Loss: 88.81016905841487
# Epoch 377/400, Validation Loss: 84.82490006508581
# Epoch 378/400, Validation Loss: 84.37189392339667
# Epoch 379/400, Validation Loss: 85.78001569512962
# Epoch 380/400, Validation Loss: 86.73001381475555
# Epoch 381/400, Validation Loss: 84.62703892402597
# Epoch 382/400, Validation Loss: 85.29170079632563
# Epoch 383/400, Validation Loss: 85.38292615578106
# Epoch 384/400, Validation Loss: 87.4676476562606
# Epoch 385/400, Validation Loss: 86.55675900155015
# Epoch 386/400, Validation Loss: 85.35843059850785
# Epoch 387/400, Validation Loss: 87.5340652393249
# Epoch 388/400, Validation Loss: 84.16113351683647
# Epoch 389/400, Validation Loss: 86.32420490883837
# Epoch 390/400, Validation Loss: 85.66275634598753
# Epoch 391/400, Validation Loss: 87.47166059983947
# Epoch 392/400, Validation Loss: 84.74575563789674
# Epoch 393/400, Validation Loss: 87.79300762919323
# Epoch 394/400, Validation Loss: 85.89498651103713
# Epoch 395/400, Validation Loss: 86.11590983129236
# Epoch 396/400, Validation Loss: 86.11354199844529
# Epoch 397/400, Validation Loss: 86.8411366257001
# Epoch 398/400, Validation Loss: 88.39726258792034
# Epoch 399/400, Validation Loss: 84.67815321556463
# Epoch 400/400, Validation Loss: 85.62242442004643

# %%
a_val, b_val = model.a.item(), model.b.item()

# Generate predictions for plotting
end_fit_x = [x_all[0], x_all[-1]]
end_fit_y = [a_val * x + b_val for x in end_fit_x]
true_fn_y = [a0 * x + b0 for x in end_fit_x]  # Assuming a0 and b0 are known true values

# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plotting data points and model predictions
axs[0].plot(x_train, y_train, 'ro', x_val, y_val, 'b^', end_fit_x, end_fit_y, 'g')
axs[0].legend(('training points', 'test points', 'final fit'), loc='upper left')

# Assuming training and validation loss history are stored in lists: train_loss_history and val_loss_history
epochs = range(1, len(train_loss_history) + 1)

# Plotting loss history
axs[1].semilogy(epochs, train_loss_history, 'r')
axs[1].semilogy(epochs, val_loss_history, 'b')
axs[1].legend(('training loss', 'validation loss'), loc='upper right')

plt.show()

# %% [markdown]
# ## 3. Exercise 1
#
# Play with the true function parameters ```a0, b0, s0``` and the ``batch_size`` value, check how it affects the convergence.
#
# 1. How change of `s0` affects convergance?
# 2. When one should stop training to prevent overfitting?
#
#
# ## 4. Training loop
#
# The training as we just saw is done iteratively, by adjusting the model parameters.
#
# We perform optimization several times for all traininng dataset. Going through all this dataset is refered to as 'epoch'.
#
# When we do training its usually done in two loops. In outer loop we iterate over all epochs. For each epoch we usually split the dataset into small chuncks, batches, and optimization it performed for all of those.
#
# It is important that data doesn't go to the training pipeline in same order. So the overall scheme looks like this (pseudocode):
#
#
# ```
# x,y = get_training_data()
# for epoch in range(number_epochs):
#    x_shfl,y_shfl = shuffle(x,y)
#
#    for mb_idx in range(number_minibatches_in_batch):
#        x_mb,y_mb = get_minibatch(x_shfl,y_shfl, mb_idx)
#
#        optimize_on(data=x_mb, labels=y_mb)
# ```
#
# ## 5. Bulding blocks of a neural network
#
# Neural network consists of layers of neurons. Each neuron perfroms 2 operations.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/Perceptron.png" alt="drawing" width="30%"/>
#
# Each neuron performs 2 operations.
#
# 1. Calculate the linear transformation of the input vector $\mathbf{x}_i$:
# $$z_i = \mathbf{w} \cdot \mathbf{x}_i + b = \sum_j {w_j x_{ij}} + b$$ where $\mathbf{w}$ is a weight vector and $b$ - a bias, and $j$ traverses each dimension of the input vector
# 2. Perform the nonlinear transformation of the result using the activation function $f$ $$y_i = f(z_i)$$
#
# In a fully connected neural network, each layer is a set of N neurons, performing different transformations of the input $\mathbf{x}_i$ of the same layer, now producing an output **vector** $ \mathbf{y} _i = f(\mathbf{z}_i) = f(W\mathbf{x}_i + \mathbf{b})$ now with a bias vector $\mathbf{b}$ and a * *matrix** of weights $W$.
#
# Since the output of each layer constitutes the input to the next layer, we can write for layer $l$: $$\mathbf{x}^l_i = f^{l-1}(\mathbf{W}^{ l-1} \mathbf{x}^{ l-1}_i + \mathbf{b}^{l-1})$$ where $\mathbf{x}_i^{l=0}$ is the vector d 'network input for data point $i$.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/MLP.png" alt="drawing" width="50%"/>
#
# To simplify building the network, we'll define a helper function, creating neuron layer with given number of outputs:

# %%
class Dense(nn.Module):
    def __init__(self, input_units, output_units, activation=None):
        """
        Fully connected layer implemented with explicit matrix multiplication.

        Parameters
        ----------
        input_units : int
            Number of input neurons
        output_units : int
            Number of output neurons
        activation : callable or None, optional
            Non-linear activation function (e.g., F.relu)
        """
        super(Dense, self).__init__()
        self.input_units = int(input_units)
        self.output_units = int(output_units)
        self.activation = activation

        # Initialize weights and biases
        self.weights = nn.Parameter(torch.randn(input_units, output_units))
        self.bias = nn.Parameter(torch.randn(output_units))

    def forward(self, x):
        """
        Forward pass through the layer.

        Parameters
        ----------
        x : torch.Tensor
            Input tensor

        Returns
        -------
        torch.Tensor
            Output of the layer
        """

        outputs = torch.matmul(x, self.weights) + self.bias

        # Apply activation function if provided
        if self.activation is not None:
            # Check if the activation function is softmax
            if self.activation == F.softmax:
                # Apply softmax with specified dimension
                outputs = self.activation(outputs, dim=1)
            else:
                # apply other activation functions normally
                outputs = self.activation(outputs)

        return outputs

# %% [markdown]
# In the case of multi-class classification, in the last layer, we can use the *softmax* transformation as a non-linear transformation. The softmax for the $j$th element of $\mathbf{z}_i$ is $$y_{ij} = \frac{e^{z_{ij}}}{\sum_{k=1}^{K} e^{z_{ik}}}$$ where $K$ is the total number of classes.
#
#
# For example. before softmax $$[1.0, 2.0, 3.0, \mathbf{4.0} ]$$ and after: $$[0.0321, 0.0871, 0.2369, \mathbf{0.6439}]$$ (now the sum is equal to one)
#
# We can also now compare the fundamental truth which could be $$[0,0,0,\mathbf{1}]$$ That is to say that class 4 is the good class and that the network predicted correctly.
# ## 6. Bulding a neural network
#
# https://medium.com/geekculture/how-visualizations-help-make-sense-of-deep-learning-a408ab00688f

# %%
n_input = 10
n_output = 2
num_datapoints = 1
input_tensor = torch.randn(num_datapoints, n_input)
dense = Dense(input_units=n_input , output_units=n_output, activation=torch.sigmoid)


# remember to matrix multiply A and B we need the shapes (a1 x a2) (b1 x b2) to be such that a2=b1
# the result will be (a1 x b2)

print(dense.weights.shape)
print(input_tensor.shape)
print(torch.matmul(input_tensor, dense.weights).shape) # this is XW  e.g. (1, 10)x(10, 2) = (1 x 2)

# notice that increasing the number of data points does not change the shape of W!
# This is important - the parameter shape should not change according to the number of datapoints, only their dimenaionality
# Out:
# torch.Size([10, 2])
# torch.Size([1, 10])
# torch.Size([1, 2])

# %%
# if we want to stack multiple dense operations together
hidden_dim = 10
dense1 =  Dense(input_units=n_input , output_units=hidden_dim, activation=torch.sigmoid)
dense2 =  Dense(input_units=hidden_dim , output_units=n_output, activation=F.softmax)
output = dense2(dense1(input_tensor))

# %%
# integrate everything into an overall model

class MyModel(nn.Module):
    def __init__(self, input_units, hidden_units, output_units):
        super(MyModel, self).__init__()
        # Define a Dense layer
        self.dense1 = Dense(input_units, hidden_units, activation=F.relu)
        # Define another Dense layer
        self.dense2 = Dense(hidden_units, output_units, activation=F.softmax)

    def forward(self, x):
        x = self.dense1(x)
        x = self.dense2(x)
        return x

    def predict(self, x):
        # Forward pass and get predictions
        preds = self.dense2(self.dense1(x))
        print(preds)  # to check values before argmax
        return torch.argmax(preds, dim=1)

# Example usage
input_units = 10
hidden_units = 5
output_units = 2
model = MyModel(input_units, hidden_units, output_units)

# Create a sample input tensor
input_tensor = torch.randn(5, input_units)

# Get predictions
predictions = model.predict(input_tensor)
print(predictions)
# Out:
# tensor([[5.6884e-01, 4.3116e-01],
#         [1.4133e-06, 1.0000e+00],
#         [5.6317e-01, 4.3683e-01],
#         [4.9481e-01, 5.0519e-01],
#         [5.8071e-02, 9.4193e-01]], grad_fn=<SoftmaxBackward0>)
# tensor([0, 1, 0, 1, 1])
